# %% [markdown]
# # 03 — Thermal comfort-cost scenarios
#
# The price input in the first version is an explicit synthetic peak/off-peak proxy. The notebook does not claim it is a utility tariff.

# %%
from pathlib import Path
import subprocess, sys
root = Path('..').resolve()
subprocess.run([sys.executable, 'scripts/run_scenarios.py', '--config', 'configs/base.yaml', '--horizon', '168'], cwd=root, check=True)

# %% [markdown]
# Compare candidate targets using `thermal_scenarios.csv` and the generated comfort-cost figure. State all parameter and scenario assumptions before interpreting the outcome.
