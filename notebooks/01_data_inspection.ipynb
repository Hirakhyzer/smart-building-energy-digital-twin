# %% [markdown]
# # 01 — ASHRAE data inspection
#
# This notebook reads local untracked files only. It does not generate model results.

# %%
from pathlib import Path
import subprocess, sys, json
root = Path('..').resolve()
subprocess.run([sys.executable, 'scripts/inspect_data.py'], cwd=root, check=True)
summary = json.loads((root / 'outputs' / 'results' / 'data_summary.json').read_text())
summary

# %% [markdown]
# ## Before forecasting
# Confirm meter types, available weather fields, candidate building IDs, time coverage, and missingness. Then configure an explicit small building subset in `configs/base.yaml`.
