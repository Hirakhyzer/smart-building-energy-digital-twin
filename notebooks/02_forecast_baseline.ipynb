# %% [markdown]
# # 02 — Chronological energy forecast baseline
#
# Configure real inspected building IDs before executing this notebook.

# %%
from pathlib import Path
import subprocess, sys
root = Path('..').resolve()
subprocess.run([sys.executable, 'scripts/run_forecast.py', '--config', 'configs/base.yaml'], cwd=root, check=True)

# %% [markdown]
# Read `outputs/results/forecast_metrics.json` and inspect the generated forecast window. Do not copy results into reports until the configuration and local input subset are documented.
